# %% [markdown]
# This notebook performs tests of the instructed PyGEM
#     capabilities
#
#     Code written by: Henning Åkesson

# %%
### imports ###
import os, sys, glob, json
# pygem imports
from pygem.setup.config import ConfigManager
# instantiate ConfigManager
config_manager = ConfigManager()
#config_manager = ConfigManager(base_dir="/uio/hypatia/geofag-felles/projects/glacmass/henning/pygem/PyGEM")

# read the config
pygem_prms = config_manager.read_config()   # NOTE: ensure that your root path in ~/PyGEM/config.yaml points to
                                            # the appropriate location. If any errors occur, check this first.
rootpath=pygem_prms['root']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 10
#       6 config_manager = ConfigManager()
#       7 #config_manager = ConfigManager(base_dir="/uio/hypatia/geofag-felles/projects/glacmass/henning/pygem/PyGEM")
#       8
#       9 # read the config
# ---> 10 pygem_prms = config_manager.read_config()   # NOTE: ensure that your root path in ~/PyGEM/config.yaml points to
#      11                                             # the appropriate location. If any errors occur, check this first.
#      12 rootpath=pygem_prms['root']
#
# File /uio/hypatia/geofag-felles/projects/glacmass/henning/pygem/PyGEM/pygem/setup/config.py:60, in ConfigManager.read_config(self, validate)
#      57     user_config = ryaml.load(f)
#      59 if validate:
# ---> 60     self._validate_config(user_config)
#      62 return user_config
#
# File /uio/hypatia/geofag-felles/projects/glacmass/henning/pygem/PyGEM/pygem/setup/config.py:109, in ConfigManager._validate_config(self, config)
#     107         sub_data = sub_data[sub_key]
#     108     else:
# --> 109         raise KeyError(f'Missing required key in configuration: {key}')
#     111 if not isinstance(sub_data, expected_type):
#     112     raise TypeError(
#     113         f"Invalid type for '{key}': expected {expected_type}, not {type(sub_data)}"
#     114     )
#
# KeyError: 'Missing required key in configuration: calib.MCMC_params.option_calib_meltextent_1d'

# %% [markdown]
# Pick a glacier of choice

# %%
glac_no = 08.01126 # Nigardsbreen, Norway
# glac_no = 11.01450 # Great Aletsch, Switzerland
# glac_no = 11.00897 # Hintereisferner, Austriadd

# %% [markdown]
# Run test simulation using IGM as dynamics option

# %%
# passing the above parameters as command line arguments:
glac_no = 15.03733
# !run_simulation -rgi_glac_number {glac_no} -ref_startyear 2000 -ref_endyear 2019 -option_dynamics IGM
